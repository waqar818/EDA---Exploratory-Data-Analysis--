# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##  (A) Gathering the Data

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# ## (B)Accessing the Data (Performing EDA)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# ## (C) Cleaning the Data

# %% [markdown]
# #### 1. Dealing with missing value

# %% [markdown]
# ##### By Dropping Column

# %%
#Dropping column 
df.drop(columns='deck', inplace=True)

# %%
df.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 488         0       3    male  30.0      0      0   8.0500        S   Third
# 361         0       2    male  29.0      1      0  27.7208        C  Second
# 55          1       1    male   NaN      0      0  35.5000        S   First
# 876         0       3    male  20.0      0      0   9.8458        S   Third
# 710         1       1  female  24.0      0      0  49.5042        C   First
# 281         0       3    male  28.0      0      0   7.8542        S   Third
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 218         1       1  female  32.0      0      0  76.2917        C   First
# 515         0       1    male  47.0      0      0  34.0208        S   First
# 697         1       3  female   NaN      0      0   7.7333        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 488    man        True  Southampton    no   True
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ##### By Replacing the Mean with missing value (Works for numeric attribute)

# %%
# Replacing missing value with mean of age
df['age'] = df.age.fillna(value = df['age'].mean())

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.224467
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df.sample(20)
# Out:
#      survived  pclass     sex        age  sibsp  parch      fare embarked  \
# 863         0       3  female  29.699118      8      2   69.5500        S
# 432         1       2  female  42.000000      1      0   26.0000        S
# 90          0       3    male  29.000000      0      0    8.0500        S
# 678         0       3  female  43.000000      1      6   46.9000        S
# 554         1       3  female  22.000000      0      0    7.7750        S
# 396         0       3  female  31.000000      0      0    7.8542        S
# 118         0       1    male  24.000000      0      1  247.5208        C
# 391         1       3    male  21.000000      0      0    7.7958        S
# 763         1       1  female  36.000000      1      2  120.0000        S
# 601         0       3    male  29.699118      0      0    7.8958        S
# 534         0       3  female  30.000000      0      0    8.6625        S
# 425         0       3    male  29.699118      0      0    7.2500        S
# ...

# %% [markdown]
# #### By Replacing Mode with missing value ( Works for catagorical attributes)

# %%
df['embarked'] = df.embarked.fillna(value = df['embarked'].mode()[0])

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.000000
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df['embark_town'] = df.embark_town.fillna(value = df['embark_town'].mode()[0])

# %%
df.isnull().sum() / len(df) * 100
# Out:
# survived       0.0
# pclass         0.0
# sex            0.0
# age            0.0
# sibsp          0.0
# parch          0.0
# fare           0.0
# embarked       0.0
# class          0.0
# who            0.0
# adult_male     0.0
# embark_town    0.0
# alive          0.0
# alone          0.0
# dtype: float64

# %% [markdown]
# #### Correcting error in data

# %% [markdown]
# ##### 1. Removing Outliers

# %% [markdown]
# #### BY Visualization and IQR method

# %%
# For 'Age'
# Removing Outliers by visualization
import seaborn as sns

sns.boxplot(data=df, y='age', x='sex')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='age'>

# %%
# Removing outliers from age

# By IQR
Q1 = df['age'].quantile(0.25)
Q3 = df['age'].quantile(0.75)
IQR = Q3 - Q1
IQR
#Calculating Lower and upper limits
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
#Removing outliers 
df = df[(df['age'] > lower) & (df['age'] < upper)]

# %%
#Removing Outliers from fare by visualzation
sns.boxplot(data=df, x='who', y='fare')
# Out:
# <AxesSubplot: xlabel='who', ylabel='fare'>

# %%
# Removing outliers from fare

# By IQR
Q1 = df['fare'].quantile(0.25)
Q3 = df['fare'].quantile(0.75)
IQR = Q3 - Q1
IQR
#Calculating Lower and upper limits
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
df = df[(df['fare'] > lower) & (df['fare'] < upper)]

# %%
sns.histplot(df['age'])
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['fare'])
# Out:
# <AxesSubplot: xlabel='fare', ylabel='Count'>

# %% [markdown]
# ##### By Z-score method

# %%
# Remove Outliers from "age" by Z-SCORE method
from scipy import stats
z_score = np.abs(stats.zscore(df['age']))
threshold = 3
df = df[(z_score < threshold)]

# %%
# Remove Outliers from "fare" by Z-SCORE method
from scipy import stats
z_score = np.abs(stats.zscore(df['fare']))
threshold = 3
df = df[(z_score < threshold)]

# %% [markdown]
# ## Finding and dropping duplicates

# %%
df.shape
# Out:
# (709, 14)

# %%
# Finding the duplicates
df.duplicated().sum()
# Out:
# 103

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (606, 14)

# %%
df.head()
# Out:
#    survived  pclass     sex        age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.000000      1      0   7.2500        S  Third
# 2         1       3  female  26.000000      0      0   7.9250        S  Third
# 3         1       1  female  35.000000      1      0  53.1000        S  First
# 4         0       3    male  35.000000      0      0   8.0500        S  Third
# 5         0       3    male  29.699118      0      0   8.4583        Q  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True
# 5    man        True   Queenstown    no   True

# %% [markdown]
# ## Data Normalization (aka data transformation)

# %% [markdown]
# #### By Min - Max Scaling

# %%
# importing libraries
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Data
df

# Select columns to normalize
column_to_normalize = ['age','fare']

#Creating scaler function 
scaler = MinMaxScaler()

#Fit and transform the data on scaler
df[column_to_normalize] = scaler.fit_transform(df[column_to_normalize])

# Checking the data 
df
# Out:
#      survived  pclass     sex       age  sibsp  parch      fare embarked  \
# 0           0       3    male  0.372549      1      0  0.128328        S
# 2           1       3  female  0.450980      0      0  0.140276        S
# 3           1       1  female  0.627451      1      0  0.939893        S
# 4           0       3    male  0.627451      0      0  0.142488        S
# 5           0       3    male  0.523512      0      0  0.149716        Q
# ..        ...     ...     ...       ...    ...    ...       ...      ...
# 885         0       3  female  0.705882      0      5  0.515525        Q
# 887         1       1  female  0.313725      0      0  0.531013        S
# 888         0       3  female  0.523512      1      2  0.415075        S
# 889         1       1    male  0.450980      0      0  0.531013        C
# 890         0       3    male  0.568627      0      0  0.137178        Q
#
#      class    who  adult_male  embark_town alive  alone
# ...

# %% [markdown]
# #### Standard Scaler

# %%
'''# importing libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Data
df

# Select columns to normalize
column_to_normalize = ['age','fare']

#Creating scaler function 
scaler = StandardScaler()

#Fit and transform the data on scaler
df[column_to_normalize] = scaler.fit_transform(df[column_to_normalize])

# Checking the data 
df'''
# Out:
# "# importing libraries\nimport pandas as pd\nfrom sklearn.preprocessing import StandardScaler\n\n# Data\ndf\n\n# Select columns to normalize\ncolumn_to_normalize = ['age','fare']\n\n#Creating scaler function \nscaler = StandardScaler()\n\n#Fit and transform the data on scaler\ndf[column_to_normalize] = scaler.fit_transform(df[column_to_normalize])\n\n# Checking the data \ndf"

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  606.000000  606.000000  606.000000  606.000000  606.000000  606.000000
# mean     0.354785    2.491749    0.494911    0.458746    0.366337    0.314126
# std      0.478844    0.724379    0.207313    0.898547    0.839789    0.225994
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.372549    0.000000    0.000000    0.139759
# 50%      0.000000    3.000000    0.523512    0.000000    0.000000    0.230106
# 75%      1.000000    3.000000    0.607843    1.000000    0.000000    0.460211
# max      1.000000    3.000000    1.000000    5.000000    6.000000    1.000000

# %% [markdown]
# ### Log Transformation

# %% [markdown]
# #### Note: We can actually do log transformation after dealing with missing values and before finding outliers, So There is a chance that outliers should remove automatically by log transformation.

# %%
boat = sns.load_dataset('titanic')
boat.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ##### Normalizaing "fare" column using log transformation
# ##### Note: Log transformation is not suitable for age

# %%
import numpy as np
boat['fare'] = boat['fare'].fillna(boat['fare'].mean())
boat['age'] = boat['age'].fillna(boat['age'].mean())

# Create an array with some data
boat['fare'] = np.log(boat['fare'])
# Log transformation is not suitable for age
# boat['age'] = np.log(boat['age'])



# Log-transform the data

boat.head()
# Out:
# c:\Users\Waqar Haider\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  22.0      1      0  1.981001        S  Third
# 1         1       1  female  38.0      1      0  4.266662        C  First
# 2         1       3  female  26.0      0      0  2.070022        S  Third
# 3         1       1  female  35.0      1      0  3.972177        S  First
# 4         0       3    male  35.0      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# ...

# %%
# Checking by Normalization 
sns.boxplot(boat, x='sex', y='fare')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='fare'>

# %% [markdown]
# ##### Normalizaing "age" column using log Min - Max Scaling
# ##### Note: Log transformation is not suitable for age thats why we are applying Min - Max scaling on it

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler


# Select columns to normalize
col = ['age']

#Creating scaler function 
scaler = MinMaxScaler()

#Fit and transform the data on scaler
boat[col] = scaler.fit_transform(boat[col])

boat.head()
# Out:
#    survived  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  0.271174      1      0  1.981001        S  Third
# 1         1       1  female  0.472229      1      0  4.266662        C  First
# 2         1       3  female  0.321438      0      0  2.070022        S  Third
# 3         1       1  female  0.434531      1      0  3.972177        S  First
# 4         0       3    male  0.434531      0      0  2.085672        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Checking normalization by visualization 
sns.histplot(boat['age'])
# Out:
# <AxesSubplot: xlabel='age', ylabel='Count'>

# %% [markdown]
# # Organizing the Data

# %%
# Adding new Column 

df['family-size'] = df['sibsp'] + df['parch']

# %%
sns.swarmplot(data=df, x='sex', y='age', hue='family-size')
# Out:
# c:\Users\Waqar Haider\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='sex', ylabel='age'>
# c:\Users\Waqar Haider\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 12.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Waqar Haider\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family-size'],
#       dtype='object')

# %%
# Renaming column

df = df.rename(columns={'survived' : 'survival'})
df.columns
# Out:
# Index(['survival', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'family-size'],
#       dtype='object')

# %%
# Making pivot table 
import pandas as pd

tab = pd.pivot_table(df, values="fare", index="who",
                     columns="survival", aggfunc=np.mean)
tab
# Out:
# survival         0         1
# who
# child     0.504026  0.371653
# man       0.261822  0.372013
# woman     0.291187  0.374216

# %%
df.head()
# Out:
#    survival  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male  0.372549      1      0  0.128328        S  Third
# 2         1       3  female  0.450980      0      0  0.140276        S  Third
# 3         1       1  female  0.627451      1      0  0.939893        S  First
# 4         0       3    male  0.627451      0      0  0.142488        S  Third
# 5         0       3    male  0.523512      0      0  0.149716        Q  Third
#
#      who  adult_male  embark_town alive  alone  family-size
# 0    man        True  Southampton    no  False            1
# 2  woman       False  Southampton   yes   True            0
# 3  woman       False  Southampton   yes  False            1
# 4    man        True  Southampton    no   True            0
# 5    man        True   Queenstown    no   True            0

# %% [markdown]
# # Saving the cleaned & Wrangled Data

# %%
# Saving the cleaned & Wrangled Data
df.to_csv("Preprocessed_data.csv")

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# #### Checking for null values

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# #### Checking the duplicate data

# %%
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# #### Dropping Duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (243, 7)

# %% [markdown]
# #### Checking the Distribution of data by visualization (BY HISTOGRAM)

# %%
df.hist(bins=40)
# Out:
# array([[<AxesSubplot: title={'center': 'total_bill'}>,
#         <AxesSubplot: title={'center': 'tip'}>],
#        [<AxesSubplot: title={'center': 'size'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# #### Checking distribution by box plot

# %%
sns.boxplot(df, y="tip", x="day")
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %% [markdown]
# #### Checking correlation

# %%
df.corr()
# Out:
# C:\Users\Waqar Haider\AppData\Local\Temp\ipykernel_17212\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             total_bill       tip      size
# total_bill    1.000000  0.674998  0.597589
# tip           0.674998  1.000000  0.488400
# size          0.597589  0.488400  1.000000

# %% [markdown]
# #### Checking correlation by heatmap

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# C:\Users\Waqar Haider\AppData\Local\Temp\ipykernel_17212\621126171.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <AxesSubplot: >

# %% [markdown]
# ### Checking correlation by scatter plot

# %%
sns.scatterplot(data=df, x='total_bill', y='tip')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# #### By LM Plot

# %%
sns.lmplot(data=df, x='total_bill', y='tip', hue="sex")
